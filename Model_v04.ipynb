# %%
import geopandas as gpd
import pandas as pd
from shapely.geometry import MultiPolygon, Polygon, Point
import numpy as np
import matplotlib.pyplot as plt
import shapely.geometry
import random

# %%
# Load highschool data
colegios = pd.read_csv('https://raw.githubusercontent.com/rmateusc/DZK_bello/main/data/geo_data/colegios_bello.csv?token=GHSAT0AAAAAABRGMKJYS3FYCLQVEU3L6FYAYRQ4WZA')
ocio = pd.read_csv('https://raw.githubusercontent.com/rmateusc/DZK_bello/main/data/geo_data/ocio.csv?token=GHSAT0AAAAAABRGMKJZZMH4IPHDA3VOYU6EYRQ4XNQ')
trabajo = pd.read_csv('https://raw.githubusercontent.com/rmateusc/DZK_bello/main/data/geo_data/trabajo.csv?token=GHSAT0AAAAAABRGMKJZVZFUNZ6WH5E5OPNIYRQ4XUQ')

# %%
colegios = colegios.rename(columns={'LONGITUD': 'x', 'LATITUD': 'y'})

# %%
# Complete Bello map
bello_map = gpd.read_file('/Users/rafaelmateus/Desktop/Modelo_PI 22.18.24/data/maps/BELLO_MAPA/bello_map.shp')
# Bello map divided by Zones(Veredas)
veredas = gpd.read_file('/Users/rafaelmateus/Desktop/Modelo_PI 22.18.24/data/maps/BELLO_VEREDAS/bello_veredas.shp')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /var/folders/nv/xg8c1lkd4bq4th3rhq8nlglw0000gn/T/ipykernel_8306/689035877.py in <module>
#       1 # Complete Bello map
#       2 bello_map = gpd.read_file('/Users/rafaelmateus/Desktop/Modelo_PI 22.18.24/data/maps/BELLO_MAPA/bello_map.shp')
# ----> 3 bello_map = gpd.read_file('https://github.com/rmateusc/DZK_bello/blob/main/data/maps/BELLO_MAPA/bello_map.shp')
#       4 # Bello map divided by Zones(Veredas)
#       5 veredas = gpd.read_file('/Users/rafaelmateus/Desktop/Modelo_PI 22.18.24/data/maps/BELLO_VEREDAS/bello_veredas.shp')
#
# /opt/anaconda3/envs/geo_env/lib/python3.9/site-packages/geopandas/io/file.py in _read_file(filename, bbox, mask, rows, **kwargs)
#     127     _check_fiona("'read_file' function")
#     128     if _is_url(filename):
# --> 129         req = _urlopen(filename)
# ...

# %%
import helper_funs

# %%
square_grid = helper_funs.square_grid(bello_map, n_cells=100)

# %%
helper_funs.plot_map_grid(bello_map, square_grid)
